# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('test_data.csv')

# %%
plt.figure(figsize=(6, 4))
plt.hist(df["age"], bins=10)
plt.title("Age distribution")
plt.xlabel("Age")
plt.ylabel("Count")
plt.show()

# %%
df.head()
# Out:
#    user_id    name  age       city signup_date   plan  sessions_30d  \
# 0     1001   Maxim   32  Rotterdam  2024-03-03   free            11
# 1     1002   Sofia   20      Kazan  2024-12-17    pro            10
# 2     1003    Olga   31      Kazan  2024-08-18   free             3
# 3     1004  Dmitry   34     Moscow  2024-08-28  basic            12
# 4     1005   Maxim   21      Kazan  2024-02-21  basic            11
#
#    revenue_usd  nps  is_active
# 0        46.98    6          1
# 1         7.84    7          1
# 2         8.00    2          1
# 3        25.09    5          1
# 4         9.84    0          1

# %%
df.columns
# Out:
# Index(['user_id', 'name', 'age', 'city', 'signup_date', 'plan', 'sessions_30d',
#        'revenue_usd', 'nps', 'is_active'],
#       dtype='object')
